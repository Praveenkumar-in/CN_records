# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveenkumar-in/CN_records/blob/main/Predict%20house%20prices%20based%20on%20house%20size.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📌 Concept: Linear Regression (Basic Machine Learning)

# Linear Regression is used to predict a value based on the relationship between variables.

# 🎯 Example:

# Predict house prices based on house size.

# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample data (House size in square feet)
X = np.array([500, 1000, 1500, 2000, 2500]).reshape(-1, 1)

# House prices
y = np.array([150000, 300000, 450000, 600000, 750000])

# Create model
model = LinearRegression()

# Train model
model.fit(X, y)

# Predict price for 1800 sq ft
predicted_price = model.predict([[1800]])

print("Predicted price for 1800 sq ft:", predicted_price[0])

# Plot data
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.xlabel("House Size (sq ft)")
plt.ylabel("Price")
plt.title("Linear Regression Example")
plt.show()
# Out:
# Predicted price for 1800 sq ft: 540000.0
